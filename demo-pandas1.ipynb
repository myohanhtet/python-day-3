# %%
import pandas as pd

my_dict = {
    "a": 1,
    "b": 2,
    "c": 3
    }
# print(my_dict)

# print(my_dict.keys())

# print(list(my_dict.keys()))

# print(my_dict.values())

# print(list(my_dict.values()))

# for key, value in my_dict.items():
#     print(f"Key {key} : Value {value}")

# data_dict = {'a': 1, 'b': 2, 'c': 3}
# series_dict = pd.Series(data_dict)
# print(series_dict)

# data = [10,20,30]
# index = ['a', 'b', 'c']
# series_custom = pd.Series(data, index=index)
# print(series_custom)

data = {
    'name': ['Alice', 'Bob', 'Charlie'],
    'age': [25, 30, 35],
    'city': ['New York', 'Los Angeles', 'Chicago']
}

df = pd.DataFrame(data)
print(df)

df.to_excel('output.xlsx', index=False)
# Out:
#       name  age         city
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
data = [
    {'name': 'Alice', 'age': 25, 'city': 'New York'},
    {'name': 'Bob', 'age': 30, 'city': 'Los Angeles'},
    {'name': 'Charlie', 'age': 35, 'city': 'Chicago'}
]

df = pd.DataFrame(data)
# print(df)

# df.tail(1)  # Display the first few rows of the DataFrame

# df[['name','age','city']]  # Access a specific column by name

# df

# df[df.age > 30]  # Filter rows based on a condition

e1 = df.iloc[0:1]  # Access a specific cell by row and column labels

# print(e1)  # Print the value of the accessed cell

# print(df)

# e2 = df.iloc[0, 0]
# print(e2)  # Print the value of the accessed cell
# Out:
#       name  age         city
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# Alice

# %%
df
# Out:
#       name  age         city
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df.iloc[[0,1],[0,2]]
# Out:
#     name         city
# 0  Alice     New York
# 1    Bob  Los Angeles

# %%
e3 = df.iat[1, 0]
print(e3)  # Print the value of the accessed cell
# Out:
# Bob

# %%
df1 = pd.read_csv('100 Sales Records.csv',encoding='utf-8');
df1  # Display the first few rows of the DataFrame
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...
